# %%
import config
import pandas as pd
import glob
from sqlalchemy import create_engine, Column, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.sql.sqltypes import Boolean, DateTime, Integer, Numeric
from sqlalchemy.orm import sessionmaker

db_string = f"postgresql://postgres:{config.db_password}@127.0.0.1:5432/market_data"

db = create_engine(db_string)

Session = sessionmaker(db)  
session = Session()

Base = declarative_base()

class Opt_put_hist(Base):
    __tablename__ = 'opt_put_hist'
    
    id = Column(Integer, primary_key=True)
    contractSymbol = Column('contractSymbol',String)
    lastTradeDate = Column('lastTradeDate',DateTime)
    strike = Column('strike',Numeric)
    lastPrice = Column('lastPrice',Numeric)
    bid = Column('bid',Numeric)
    ask = Column('ask',Numeric)
    change = Column('change',Numeric)
    percentChange = Column('percentChange',Numeric)
    volume = Column('volume',Numeric)
    openInterest = Column('openInterest',Numeric)
    impliedVolatility = Column('impliedVolatility',Numeric)
    inTheMoney = Column('inTheMoney',Boolean)
    contractSize = Column('contractSize',String)
    currency = Column('currency',String)
    ticker = Column('ticker',String)
    call_put = Column('call_put',String)
    exp_date = Column('exp_date',DateTime)

    # def __repr__(self):
    #     return "<Stock_hist("date='%s')

Base.metadata.create_all(db)

filenames = glob.glob('Resources/opt_puts/*.csv')

for filename in filenames:
    file_name = f"{filename}"
    df = pd.read_csv(file_name)
    df.to_sql(name=Opt_put_hist.__tablename__, con=db, if_exists='append', index=False)


session = sessionmaker()
session.configure(bind=db)
s = session()

results = s.query(Opt_put_hist).all()
for r in results:
    print(r)
# Out:
# <__main__.Opt_put_hist object at 0x000001FB3BD69B48>
# <__main__.Opt_put_hist object at 0x000001FB3BD69CC8>
# <__main__.Opt_put_hist object at 0x000001FB3BD69DC8>
# <__main__.Opt_put_hist object at 0x000001FB3BD69EC8>
# <__main__.Opt_put_hist object at 0x000001FB3BD69FC8>
# <__main__.Opt_put_hist object at 0x000001FB3BA55148>
# <__main__.Opt_put_hist object at 0x000001FB3BA55248>
# <__main__.Opt_put_hist object at 0x000001FB3BA55348>
# <__main__.Opt_put_hist object at 0x000001FB3BA55448>
# <__main__.Opt_put_hist object at 0x000001FB3BA55508>
# <__main__.Opt_put_hist object at 0x000001FB3BA55608>
# <__main__.Opt_put_hist object at 0x000001FB3BA55708>
# <__main__.Opt_put_hist object at 0x000001FB3BA55808>
# <__main__.Opt_put_hist object at 0x000001FB3BA55908>
# <__main__.Opt_put_hist object at 0x000001FB3BA55A08>
# <__main__.Opt_put_hist object at 0x000001FB3BA55B08>
# <__main__.Opt_put_hist object at 0x000001FB3BA55C08>
# <__main__.Opt_put_hist object at 0x000001FB3BA55D08>
# <__main__.Opt_put_hist object at 0x000001FB3BA55E08>
# <__main__.Opt_put_hist object at 0x000001FB3BA55F08>
# <__main__.Opt_put_hist object at 0x000001FB3AC68048>
# <__main__.Opt_put_hist object at 0x000001FB3AC68148>
# <__main__.Opt_put_hist object at 0x000001FB3AC68248>
# <__main__.Opt_put_hist object at 0x000001FB3AC68348>
# <__main__.Opt_put_hist object at 0x000001FB3AC68448>
# <__main__.Opt_put_hist object at 0x000001FB3AC68548>
# <__main__.Opt_put_hist object at 0x000001FB3AC68648>
# <__main__.Opt_put_hist object at 0x000001FB3AC68748>
# <__main__.Opt_put_hist object at 0x000001FB3AC68848>
# <__main__.Opt_put_hist object at 0x000001FB3AC68948>
# <__main__.Opt_put_hist object at 0x000001FB3AC68A48>
# <__main__.Opt_put_hist object at 0x000001FB3AC68B48>
# <__main__.Opt_put_hist object at 0x000001FB3AC68C48>
# <__main__.Opt_put_hist object at 0x000001FB3AC68D48>
# <__main__.Opt_put_hist object at 0x000001FB3AC68E48>
# <__main__.Opt_put_hist object at 0x000001FB3AC68F48>
# <__main__.Opt_put_hist object at 0x000001FB3AD06088>
# <__main__.Opt_put_hist object at 0x000001FB3AD06188>
# <__main__.Opt_put_hist object at 0x000001FB3AD06288>
# <__main__.Opt_put_hist object at 0x000001FB3AD06388>
# <__main__.Opt_put_hist object at 0x000001FB3AD06488>
# <__main__.Opt_put_hist object at 0x000001FB3AD06588>
# <__main__.Opt_put_hist object at 0x000001FB3AD06688>
# <__main__.Opt_put_hist object at 0x000001FB3AD06788>
# <__main__.Opt_put_hist object at 0x000001FB3AD06888>
# <__main__.Opt_put_hist object at 0x000001FB3AD06988>
# <__main__.Opt_put_hist object at 0x000001FB3AD06A88>
# <__main__.Opt_put_hist object at 0x000001FB3AD06B88>
# <__main__.Opt_put_hist object at 0x000001FB3AD06C88>
# <__main__.Opt_put_hist object at 0x000001FB3AD06D88>
# <__main__.Opt_put_hist object at 0x000001FB3AD06E88>
# <__main__.Opt_put_hist object at 0x000001FB3AD06F88>
# <__main__.Opt_put_hist object at 0x000001FB3AD380C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD381C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD382C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD383C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD384C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD385C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD386C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD387C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD388C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD389C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38AC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38BC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38CC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38DC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38EC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD38FC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE28108>
# <__main__.Opt_put_hist object at 0x000001FB3AE28208>
# <__main__.Opt_put_hist object at 0x000001FB3AE28308>
# <__main__.Opt_put_hist object at 0x000001FB3AE28408>
# <__main__.Opt_put_hist object at 0x000001FB3AE28508>
# <__main__.Opt_put_hist object at 0x000001FB3AE28608>
# <__main__.Opt_put_hist object at 0x000001FB3AE28708>
# <__main__.Opt_put_hist object at 0x000001FB3AE28808>
# <__main__.Opt_put_hist object at 0x000001FB3AE28908>
# <__main__.Opt_put_hist object at 0x000001FB3AE28A08>
# <__main__.Opt_put_hist object at 0x000001FB3AE28B08>
# <__main__.Opt_put_hist object at 0x000001FB3AE28C08>
# <__main__.Opt_put_hist object at 0x000001FB3AE28D08>
# <__main__.Opt_put_hist object at 0x000001FB3AE28E08>
# <__main__.Opt_put_hist object at 0x000001FB3AE28F08>
# <__main__.Opt_put_hist object at 0x000001FB3AED0048>
# <__main__.Opt_put_hist object at 0x000001FB3AED0148>
# <__main__.Opt_put_hist object at 0x000001FB3AED0248>
# <__main__.Opt_put_hist object at 0x000001FB3AED0348>
# <__main__.Opt_put_hist object at 0x000001FB3AED0448>
# <__main__.Opt_put_hist object at 0x000001FB3AED0548>
# <__main__.Opt_put_hist object at 0x000001FB3AED0648>
# <__main__.Opt_put_hist object at 0x000001FB3AED0748>
# <__main__.Opt_put_hist object at 0x000001FB3AED0848>
# <__main__.Opt_put_hist object at 0x000001FB3AED0948>
# <__main__.Opt_put_hist object at 0x000001FB3AED0A48>
# <__main__.Opt_put_hist object at 0x000001FB3AED0B48>
# <__main__.Opt_put_hist object at 0x000001FB3AED0C48>
# <__main__.Opt_put_hist object at 0x000001FB3AED0D48>
# <__main__.Opt_put_hist object at 0x000001FB3AED0E48>
# <__main__.Opt_put_hist object at 0x000001FB3AED0F48>
# <__main__.Opt_put_hist object at 0x000001FB3B148088>
# <__main__.Opt_put_hist object at 0x000001FB3B148188>
# <__main__.Opt_put_hist object at 0x000001FB3B148288>
# <__main__.Opt_put_hist object at 0x000001FB3B148388>
# <__main__.Opt_put_hist object at 0x000001FB3B148488>
# <__main__.Opt_put_hist object at 0x000001FB3B148588>
# <__main__.Opt_put_hist object at 0x000001FB3B148688>
# <__main__.Opt_put_hist object at 0x000001FB3B148788>
# <__main__.Opt_put_hist object at 0x000001FB3B148888>
# <__main__.Opt_put_hist object at 0x000001FB3B148988>
# <__main__.Opt_put_hist object at 0x000001FB3B148A88>
# <__main__.Opt_put_hist object at 0x000001FB3B148B88>
# <__main__.Opt_put_hist object at 0x000001FB3B148C88>
# <__main__.Opt_put_hist object at 0x000001FB3B148D88>
# <__main__.Opt_put_hist object at 0x000001FB3B148E88>
# <__main__.Opt_put_hist object at 0x000001FB3B148F88>
# <__main__.Opt_put_hist object at 0x000001FB3B1680C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1681C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1682C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1683C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1684C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1685C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1686C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1687C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1688C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1689C8>
# <__main__.Opt_put_hist object at 0x000001FB3B168AC8>
# <__main__.Opt_put_hist object at 0x000001FB3B168BC8>
# <__main__.Opt_put_hist object at 0x000001FB3B168CC8>
# <__main__.Opt_put_hist object at 0x000001FB3B168DC8>
# <__main__.Opt_put_hist object at 0x000001FB3B168EC8>
# <__main__.Opt_put_hist object at 0x000001FB3B168FC8>
# <__main__.Opt_put_hist object at 0x000001FB3B220108>
# <__main__.Opt_put_hist object at 0x000001FB3B220208>
# <__main__.Opt_put_hist object at 0x000001FB3B220308>
# <__main__.Opt_put_hist object at 0x000001FB3B220408>
# <__main__.Opt_put_hist object at 0x000001FB3B220508>
# <__main__.Opt_put_hist object at 0x000001FB3B220608>
# <__main__.Opt_put_hist object at 0x000001FB3B220708>
# <__main__.Opt_put_hist object at 0x000001FB3B220808>
# <__main__.Opt_put_hist object at 0x000001FB3B220908>
# <__main__.Opt_put_hist object at 0x000001FB3B220A08>
# <__main__.Opt_put_hist object at 0x000001FB3B220B08>
# <__main__.Opt_put_hist object at 0x000001FB3B220C08>
# <__main__.Opt_put_hist object at 0x000001FB3B220D08>
# <__main__.Opt_put_hist object at 0x000001FB3B220E08>
# <__main__.Opt_put_hist object at 0x000001FB3B220F08>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5048>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5148>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5248>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5348>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5448>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5548>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5648>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5748>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5848>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5948>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5A48>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5B48>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5C48>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5D48>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5E48>
# <__main__.Opt_put_hist object at 0x000001FB3B2C5F48>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7088>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7188>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7288>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7388>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7488>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7588>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7688>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7788>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7888>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7988>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7A88>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7B88>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7C88>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7D88>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7E88>
# <__main__.Opt_put_hist object at 0x000001FB3B2E7F88>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE0C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE1C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE2C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE3C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE4C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE5C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE6C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE7C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE8C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DE9C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DEAC8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DEBC8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DECC8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DEDC8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DEEC8>
# <__main__.Opt_put_hist object at 0x000001FB3B3DEFC8>
# <__main__.Opt_put_hist object at 0x000001FB3B484108>
# <__main__.Opt_put_hist object at 0x000001FB3B484208>
# <__main__.Opt_put_hist object at 0x000001FB3B484308>
# <__main__.Opt_put_hist object at 0x000001FB3B484408>
# <__main__.Opt_put_hist object at 0x000001FB3B484508>
# <__main__.Opt_put_hist object at 0x000001FB3B484608>
# <__main__.Opt_put_hist object at 0x000001FB3B484708>
# <__main__.Opt_put_hist object at 0x000001FB3B484808>
# <__main__.Opt_put_hist object at 0x000001FB3B484908>
# <__main__.Opt_put_hist object at 0x000001FB3B484A08>
# <__main__.Opt_put_hist object at 0x000001FB3B484B08>
# <__main__.Opt_put_hist object at 0x000001FB3B484C08>
# <__main__.Opt_put_hist object at 0x000001FB3B484D08>
# <__main__.Opt_put_hist object at 0x000001FB3B484E08>
# <__main__.Opt_put_hist object at 0x000001FB3B484F08>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE048>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE148>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE248>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE348>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE448>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE548>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE648>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE748>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE848>
# <__main__.Opt_put_hist object at 0x000001FB3B4AE948>
# <__main__.Opt_put_hist object at 0x000001FB3B4AEA48>
# <__main__.Opt_put_hist object at 0x000001FB3B4AEB48>
# <__main__.Opt_put_hist object at 0x000001FB3B4AEC48>
# <__main__.Opt_put_hist object at 0x000001FB3B4AED48>
# <__main__.Opt_put_hist object at 0x000001FB3B4AEE48>
# <__main__.Opt_put_hist object at 0x000001FB3B4AEF48>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE088>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE188>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE288>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE388>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE488>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE588>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE688>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE788>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE888>
# <__main__.Opt_put_hist object at 0x000001FB3B5DE988>
# <__main__.Opt_put_hist object at 0x000001FB3B5DEA88>
# <__main__.Opt_put_hist object at 0x000001FB3B5DEB88>
# <__main__.Opt_put_hist object at 0x000001FB3B5DEC88>
# <__main__.Opt_put_hist object at 0x000001FB3B5DED88>
# <__main__.Opt_put_hist object at 0x000001FB3B5DEE88>
# <__main__.Opt_put_hist object at 0x000001FB3B5DEF88>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF0C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF1C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF2C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF3C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF4C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF5C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF6C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF7C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF8C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CF9C8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFAC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFBC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFCC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFDC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFEC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6CFFC8>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA108>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA208>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA308>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA408>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA508>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA608>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA708>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA808>
# <__main__.Opt_put_hist object at 0x000001FB3B6FA908>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAA08>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAB08>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAC08>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAD08>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAE08>
# <__main__.Opt_put_hist object at 0x000001FB3B6FAF08>
# <__main__.Opt_put_hist object at 0x000001FB3B829048>
# <__main__.Opt_put_hist object at 0x000001FB3B829148>
# <__main__.Opt_put_hist object at 0x000001FB3B829248>
# <__main__.Opt_put_hist object at 0x000001FB3B829348>
# <__main__.Opt_put_hist object at 0x000001FB3B829448>
# <__main__.Opt_put_hist object at 0x000001FB3B829548>
# <__main__.Opt_put_hist object at 0x000001FB3B829648>
# <__main__.Opt_put_hist object at 0x000001FB3B829748>
# <__main__.Opt_put_hist object at 0x000001FB3B829848>
# <__main__.Opt_put_hist object at 0x000001FB3B829948>
# <__main__.Opt_put_hist object at 0x000001FB3B829A48>
# <__main__.Opt_put_hist object at 0x000001FB3B829B48>
# <__main__.Opt_put_hist object at 0x000001FB3B829C48>
# <__main__.Opt_put_hist object at 0x000001FB3B829D48>
# <__main__.Opt_put_hist object at 0x000001FB3B829E48>
# <__main__.Opt_put_hist object at 0x000001FB3B829F48>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0088>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0188>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0288>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0388>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0488>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0588>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0688>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0788>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0888>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0988>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0A88>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0B88>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0C88>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0D88>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0E88>
# <__main__.Opt_put_hist object at 0x000001FB3B8D0F88>
# <__main__.Opt_put_hist object at 0x000001FB3B8F90C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F91C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F92C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F93C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F94C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F95C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F96C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F97C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F98C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F99C8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9AC8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9BC8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9CC8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9DC8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9EC8>
# <__main__.Opt_put_hist object at 0x000001FB3B8F9FC8>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8108>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8208>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8308>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8408>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8508>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8608>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8708>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8808>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8908>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8A08>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8B08>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8C08>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8D08>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8E08>
# <__main__.Opt_put_hist object at 0x000001FB3B9A8F08>
# <__main__.Opt_put_hist object at 0x000001FB3AB89048>
# <__main__.Opt_put_hist object at 0x000001FB3AB89148>
# <__main__.Opt_put_hist object at 0x000001FB3AB89248>
# <__main__.Opt_put_hist object at 0x000001FB3AB89348>
# <__main__.Opt_put_hist object at 0x000001FB3AB89448>
# <__main__.Opt_put_hist object at 0x000001FB3AB89548>
# <__main__.Opt_put_hist object at 0x000001FB3AB89648>
# <__main__.Opt_put_hist object at 0x000001FB3AB89748>
# <__main__.Opt_put_hist object at 0x000001FB3AB89848>
# <__main__.Opt_put_hist object at 0x000001FB3AB89948>
# <__main__.Opt_put_hist object at 0x000001FB3AB89A48>
# <__main__.Opt_put_hist object at 0x000001FB3AB89B48>
# <__main__.Opt_put_hist object at 0x000001FB3AB89C48>
# <__main__.Opt_put_hist object at 0x000001FB3AB89D48>
# <__main__.Opt_put_hist object at 0x000001FB3AB89E48>
# <__main__.Opt_put_hist object at 0x000001FB3AB89F48>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB088>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB188>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB288>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB388>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB488>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB588>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB688>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB788>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB888>
# <__main__.Opt_put_hist object at 0x000001FB3ABBB988>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBA88>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBB88>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBC88>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBD88>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBE88>
# <__main__.Opt_put_hist object at 0x000001FB3ABBBF88>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB0C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB1C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB2C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB3C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB4C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB5C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB6C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB7C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB8C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDB9C8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBAC8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBBC8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBCC8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBDC8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBEC8>
# <__main__.Opt_put_hist object at 0x000001FB3ABDBFC8>
# <__main__.Opt_put_hist object at 0x000001FB3AC04108>
# <__main__.Opt_put_hist object at 0x000001FB3AC04208>
# <__main__.Opt_put_hist object at 0x000001FB3AC04308>
# <__main__.Opt_put_hist object at 0x000001FB3AC04408>
# <__main__.Opt_put_hist object at 0x000001FB3AC04508>
# <__main__.Opt_put_hist object at 0x000001FB3AC04608>
# <__main__.Opt_put_hist object at 0x000001FB3AC04708>
# <__main__.Opt_put_hist object at 0x000001FB3AC04808>
# <__main__.Opt_put_hist object at 0x000001FB3AC04908>
# <__main__.Opt_put_hist object at 0x000001FB3AC04A08>
# <__main__.Opt_put_hist object at 0x000001FB3AC04B08>
# <__main__.Opt_put_hist object at 0x000001FB3AC04C08>
# <__main__.Opt_put_hist object at 0x000001FB3AC04D08>
# <__main__.Opt_put_hist object at 0x000001FB3AC04E08>
# <__main__.Opt_put_hist object at 0x000001FB3AC04F08>
# <__main__.Opt_put_hist object at 0x000001FB3AC36048>
# <__main__.Opt_put_hist object at 0x000001FB3AC36148>
# <__main__.Opt_put_hist object at 0x000001FB3AC36248>
# <__main__.Opt_put_hist object at 0x000001FB3AC36348>
# <__main__.Opt_put_hist object at 0x000001FB3AC36448>
# <__main__.Opt_put_hist object at 0x000001FB3AC36548>
# <__main__.Opt_put_hist object at 0x000001FB3AC36648>
# <__main__.Opt_put_hist object at 0x000001FB3AC36748>
# <__main__.Opt_put_hist object at 0x000001FB3AC36848>
# <__main__.Opt_put_hist object at 0x000001FB3AC36948>
# <__main__.Opt_put_hist object at 0x000001FB3AC36A48>
# <__main__.Opt_put_hist object at 0x000001FB3AC36B48>
# <__main__.Opt_put_hist object at 0x000001FB3AC36C48>
# <__main__.Opt_put_hist object at 0x000001FB3AC36D48>
# <__main__.Opt_put_hist object at 0x000001FB3AC36E48>
# <__main__.Opt_put_hist object at 0x000001FB3AC36F48>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A088>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A188>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A288>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A388>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A488>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A588>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A688>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A788>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A888>
# <__main__.Opt_put_hist object at 0x000001FB3AC8A988>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AA88>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AB88>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AC88>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AD88>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AE88>
# <__main__.Opt_put_hist object at 0x000001FB3AC8AF88>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC0C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC1C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC2C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC3C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC4C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC5C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC6C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC7C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC8C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBC9C8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCAC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCBC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCCC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCDC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCEC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACBCFC8>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD108>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD208>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD308>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD408>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD508>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD608>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD708>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD808>
# <__main__.Opt_put_hist object at 0x000001FB3ACDD908>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDA08>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDB08>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDC08>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDD08>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDE08>
# <__main__.Opt_put_hist object at 0x000001FB3ACDDF08>
# <__main__.Opt_put_hist object at 0x000001FB3AD40048>
# <__main__.Opt_put_hist object at 0x000001FB3AD40148>
# <__main__.Opt_put_hist object at 0x000001FB3AD40248>
# <__main__.Opt_put_hist object at 0x000001FB3AD40348>
# <__main__.Opt_put_hist object at 0x000001FB3AD40448>
# <__main__.Opt_put_hist object at 0x000001FB3AD40548>
# <__main__.Opt_put_hist object at 0x000001FB3AD40648>
# <__main__.Opt_put_hist object at 0x000001FB3AD40748>
# <__main__.Opt_put_hist object at 0x000001FB3AD40848>
# <__main__.Opt_put_hist object at 0x000001FB3AD40948>
# <__main__.Opt_put_hist object at 0x000001FB3AD40A48>
# <__main__.Opt_put_hist object at 0x000001FB3AD40B48>
# <__main__.Opt_put_hist object at 0x000001FB3AD40C48>
# <__main__.Opt_put_hist object at 0x000001FB3AD40D48>
# <__main__.Opt_put_hist object at 0x000001FB3AD40E48>
# <__main__.Opt_put_hist object at 0x000001FB3AD40F48>
# <__main__.Opt_put_hist object at 0x000001FB3AD69088>
# <__main__.Opt_put_hist object at 0x000001FB3AD69188>
# <__main__.Opt_put_hist object at 0x000001FB3AD69288>
# <__main__.Opt_put_hist object at 0x000001FB3AD69388>
# <__main__.Opt_put_hist object at 0x000001FB3AD69488>
# <__main__.Opt_put_hist object at 0x000001FB3AD69588>
# <__main__.Opt_put_hist object at 0x000001FB3AD69688>
# <__main__.Opt_put_hist object at 0x000001FB3AD69788>
# <__main__.Opt_put_hist object at 0x000001FB3AD69888>
# <__main__.Opt_put_hist object at 0x000001FB3AD69988>
# <__main__.Opt_put_hist object at 0x000001FB3AD69A88>
# <__main__.Opt_put_hist object at 0x000001FB3AD69B88>
# <__main__.Opt_put_hist object at 0x000001FB3AD69C88>
# <__main__.Opt_put_hist object at 0x000001FB3AD69D88>
# <__main__.Opt_put_hist object at 0x000001FB3AD69E88>
# <__main__.Opt_put_hist object at 0x000001FB3AD69F88>
# <__main__.Opt_put_hist object at 0x000001FB3AD940C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD941C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD942C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD943C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD944C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD945C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD946C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD947C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD948C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD949C8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94AC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94BC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94CC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94DC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94EC8>
# <__main__.Opt_put_hist object at 0x000001FB3AD94FC8>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD108>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD208>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD308>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD408>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD508>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD608>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD708>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD808>
# <__main__.Opt_put_hist object at 0x000001FB3ADBD908>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDA08>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDB08>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDC08>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDD08>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDE08>
# <__main__.Opt_put_hist object at 0x000001FB3ADBDF08>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7048>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7148>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7248>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7348>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7448>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7548>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7648>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7748>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7848>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7948>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7A48>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7B48>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7C48>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7D48>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7E48>
# <__main__.Opt_put_hist object at 0x000001FB3ADE7F48>
# <__main__.Opt_put_hist object at 0x000001FB3AE41088>
# <__main__.Opt_put_hist object at 0x000001FB3AE41188>
# <__main__.Opt_put_hist object at 0x000001FB3AE41288>
# <__main__.Opt_put_hist object at 0x000001FB3AE41388>
# <__main__.Opt_put_hist object at 0x000001FB3AE41488>
# <__main__.Opt_put_hist object at 0x000001FB3AE41588>
# <__main__.Opt_put_hist object at 0x000001FB3AE41688>
# <__main__.Opt_put_hist object at 0x000001FB3AE41788>
# <__main__.Opt_put_hist object at 0x000001FB3AE41888>
# <__main__.Opt_put_hist object at 0x000001FB3AE41988>
# <__main__.Opt_put_hist object at 0x000001FB3AE41A88>
# <__main__.Opt_put_hist object at 0x000001FB3AE41B88>
# <__main__.Opt_put_hist object at 0x000001FB3AE41C88>
# <__main__.Opt_put_hist object at 0x000001FB3AE41D88>
# <__main__.Opt_put_hist object at 0x000001FB3AE41E88>
# <__main__.Opt_put_hist object at 0x000001FB3AE41F88>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C0C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C1C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C2C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C3C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C4C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C5C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C6C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C7C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C8C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6C9C8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CAC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CBC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CCC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CDC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CEC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE6CFC8>
# <__main__.Opt_put_hist object at 0x000001FB3AE96108>
# <__main__.Opt_put_hist object at 0x000001FB3AE96208>
# <__main__.Opt_put_hist object at 0x000001FB3AE96308>
# <__main__.Opt_put_hist object at 0x000001FB3AE96408>
# <__main__.Opt_put_hist object at 0x000001FB3AE96508>
# <__main__.Opt_put_hist object at 0x000001FB3AE96608>
# <__main__.Opt_put_hist object at 0x000001FB3AE96708>
# <__main__.Opt_put_hist object at 0x000001FB3AE96808>
# <__main__.Opt_put_hist object at 0x000001FB3AE96908>
# <__main__.Opt_put_hist object at 0x000001FB3AE96A08>
# <__main__.Opt_put_hist object at 0x000001FB3AE96B08>
# <__main__.Opt_put_hist object at 0x000001FB3AE96C08>
# <__main__.Opt_put_hist object at 0x000001FB3AE96D08>
# <__main__.Opt_put_hist object at 0x000001FB3AE96E08>
# <__main__.Opt_put_hist object at 0x000001FB3AE96F08>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF048>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF148>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF248>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF348>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF448>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF548>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF648>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF748>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF848>
# <__main__.Opt_put_hist object at 0x000001FB3AEBF948>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFA48>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFB48>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFC48>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFD48>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFE48>
# <__main__.Opt_put_hist object at 0x000001FB3AEBFF48>
# <__main__.Opt_put_hist object at 0x000001FB3B026088>
# <__main__.Opt_put_hist object at 0x000001FB3B026188>
# <__main__.Opt_put_hist object at 0x000001FB3B026288>
# <__main__.Opt_put_hist object at 0x000001FB3B026388>
# <__main__.Opt_put_hist object at 0x000001FB3B026488>
# <__main__.Opt_put_hist object at 0x000001FB3B026588>
# <__main__.Opt_put_hist object at 0x000001FB3B026688>
# <__main__.Opt_put_hist object at 0x000001FB3B026788>
# <__main__.Opt_put_hist object at 0x000001FB3B026888>
# <__main__.Opt_put_hist object at 0x000001FB3B026988>
# <__main__.Opt_put_hist object at 0x000001FB3B026A88>
# <__main__.Opt_put_hist object at 0x000001FB3B026B88>
# <__main__.Opt_put_hist object at 0x000001FB3B026C88>
# <__main__.Opt_put_hist object at 0x000001FB3B026D88>
# <__main__.Opt_put_hist object at 0x000001FB3B026E88>
# <__main__.Opt_put_hist object at 0x000001FB3B026F88>
# <__main__.Opt_put_hist object at 0x000001FB3B04E0C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E1C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E2C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E3C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E4C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E5C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E6C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E7C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E8C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04E9C8>
# <__main__.Opt_put_hist object at 0x000001FB3B04EAC8>
# <__main__.Opt_put_hist object at 0x000001FB3B04EBC8>
# <__main__.Opt_put_hist object at 0x000001FB3B04ECC8>
# <__main__.Opt_put_hist object at 0x000001FB3B04EDC8>
# <__main__.Opt_put_hist object at 0x000001FB3B04EEC8>
# <__main__.Opt_put_hist object at 0x000001FB3B04EFC8>
# <__main__.Opt_put_hist object at 0x000001FB3B06D108>
# <__main__.Opt_put_hist object at 0x000001FB3B06D208>
# <__main__.Opt_put_hist object at 0x000001FB3B06D308>
# <__main__.Opt_put_hist object at 0x000001FB3B06D408>
# <__main__.Opt_put_hist object at 0x000001FB3B06D508>
# <__main__.Opt_put_hist object at 0x000001FB3B06D608>
# <__main__.Opt_put_hist object at 0x000001FB3B06D708>
# <__main__.Opt_put_hist object at 0x000001FB3B06D808>
# <__main__.Opt_put_hist object at 0x000001FB3B06D908>
# <__main__.Opt_put_hist object at 0x000001FB3B06DA08>
# <__main__.Opt_put_hist object at 0x000001FB3B06DB08>
# <__main__.Opt_put_hist object at 0x000001FB3B06DC08>
# <__main__.Opt_put_hist object at 0x000001FB3B06DD08>
# <__main__.Opt_put_hist object at 0x000001FB3B06DE08>
# <__main__.Opt_put_hist object at 0x000001FB3B06DF08>
# <__main__.Opt_put_hist object at 0x000001FB3B09E048>
# <__main__.Opt_put_hist object at 0x000001FB3B09E148>
# <__main__.Opt_put_hist object at 0x000001FB3B09E248>
# <__main__.Opt_put_hist object at 0x000001FB3B09E348>
# <__main__.Opt_put_hist object at 0x000001FB3B09E448>
# <__main__.Opt_put_hist object at 0x000001FB3B09E548>
# <__main__.Opt_put_hist object at 0x000001FB3B09E648>
# <__main__.Opt_put_hist object at 0x000001FB3B09E748>
# <__main__.Opt_put_hist object at 0x000001FB3B09E848>
# <__main__.Opt_put_hist object at 0x000001FB3B09E948>
# <__main__.Opt_put_hist object at 0x000001FB3B09EA48>
# <__main__.Opt_put_hist object at 0x000001FB3B09EB48>
# <__main__.Opt_put_hist object at 0x000001FB3B09EC48>
# <__main__.Opt_put_hist object at 0x000001FB3B09ED48>
# <__main__.Opt_put_hist object at 0x000001FB3B09EE48>
# <__main__.Opt_put_hist object at 0x000001FB3B09EF48>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7088>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7188>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7288>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7388>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7488>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7588>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7688>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7788>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7888>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7988>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7A88>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7B88>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7C88>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7D88>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7E88>
# <__main__.Opt_put_hist object at 0x000001FB3B0B7F88>
# <__main__.Opt_put_hist object at 0x000001FB3B0E70C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E71C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E72C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E73C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E74C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E75C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E76C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E77C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E78C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E79C8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7AC8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7BC8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7CC8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7DC8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7EC8>
# <__main__.Opt_put_hist object at 0x000001FB3B0E7FC8>
# <__main__.Opt_put_hist object at 0x000001FB3B10F108>
# <__main__.Opt_put_hist object at 0x000001FB3B10F208>
# <__main__.Opt_put_hist object at 0x000001FB3B10F308>
# <__main__.Opt_put_hist object at 0x000001FB3B10F408>
# <__main__.Opt_put_hist object at 0x000001FB3B10F508>
# <__main__.Opt_put_hist object at 0x000001FB3B10F608>
# <__main__.Opt_put_hist object at 0x000001FB3B10F708>
# <__main__.Opt_put_hist object at 0x000001FB3B10F808>
# <__main__.Opt_put_hist object at 0x000001FB3B10F908>
# <__main__.Opt_put_hist object at 0x000001FB3B10FA08>
# <__main__.Opt_put_hist object at 0x000001FB3B10FB08>
# <__main__.Opt_put_hist object at 0x000001FB3B10FC08>
# <__main__.Opt_put_hist object at 0x000001FB3B10FD08>
# <__main__.Opt_put_hist object at 0x000001FB3B10FE08>
# <__main__.Opt_put_hist object at 0x000001FB3B10FF08>
# <__main__.Opt_put_hist object at 0x000001FB3B12F048>
# <__main__.Opt_put_hist object at 0x000001FB3B12F148>
# <__main__.Opt_put_hist object at 0x000001FB3B12F248>
# <__main__.Opt_put_hist object at 0x000001FB3B12F348>
# <__main__.Opt_put_hist object at 0x000001FB3B12F448>
# <__main__.Opt_put_hist object at 0x000001FB3B12F548>
# <__main__.Opt_put_hist object at 0x000001FB3B12F648>
# <__main__.Opt_put_hist object at 0x000001FB3B12F748>
# <__main__.Opt_put_hist object at 0x000001FB3B12F848>
# <__main__.Opt_put_hist object at 0x000001FB3B12F948>
# <__main__.Opt_put_hist object at 0x000001FB3B12FA48>
# <__main__.Opt_put_hist object at 0x000001FB3B12FB48>
# <__main__.Opt_put_hist object at 0x000001FB3B12FC48>
# <__main__.Opt_put_hist object at 0x000001FB3B12FD48>
# <__main__.Opt_put_hist object at 0x000001FB3B12FE48>
# <__main__.Opt_put_hist object at 0x000001FB3B12FF48>
# <__main__.Opt_put_hist object at 0x000001FB3B19A088>
# <__main__.Opt_put_hist object at 0x000001FB3B19A188>
# <__main__.Opt_put_hist object at 0x000001FB3B19A288>
# <__main__.Opt_put_hist object at 0x000001FB3B19A388>
# <__main__.Opt_put_hist object at 0x000001FB3B19A488>
# <__main__.Opt_put_hist object at 0x000001FB3B19A588>
# <__main__.Opt_put_hist object at 0x000001FB3B19A688>
# <__main__.Opt_put_hist object at 0x000001FB3B19A788>
# <__main__.Opt_put_hist object at 0x000001FB3B19A888>
# <__main__.Opt_put_hist object at 0x000001FB3B19A988>
# <__main__.Opt_put_hist object at 0x000001FB3B19AA88>
# <__main__.Opt_put_hist object at 0x000001FB3B19AB88>
# <__main__.Opt_put_hist object at 0x000001FB3B19AC88>
# <__main__.Opt_put_hist object at 0x000001FB3B19AD88>
# <__main__.Opt_put_hist object at 0x000001FB3B19AE88>
# <__main__.Opt_put_hist object at 0x000001FB3B19AF88>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC0C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC1C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC2C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC3C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC4C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC5C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC6C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC7C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC8C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BC9C8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCAC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCBC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCCC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCDC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCEC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1BCFC8>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6108>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6208>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6308>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6408>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6508>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6608>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6708>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6808>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6908>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6A08>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6B08>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6C08>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6D08>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6E08>
# <__main__.Opt_put_hist object at 0x000001FB3B1E6F08>
# <__main__.Opt_put_hist object at 0x000001FB3B24A048>
# <__main__.Opt_put_hist object at 0x000001FB3B24A148>
# <__main__.Opt_put_hist object at 0x000001FB3B24A248>
# <__main__.Opt_put_hist object at 0x000001FB3B24A348>
# <__main__.Opt_put_hist object at 0x000001FB3B24A448>
# <__main__.Opt_put_hist object at 0x000001FB3B24A548>
# <__main__.Opt_put_hist object at 0x000001FB3B24A648>
# <__main__.Opt_put_hist object at 0x000001FB3B24A748>
# <__main__.Opt_put_hist object at 0x000001FB3B24A848>
# <__main__.Opt_put_hist object at 0x000001FB3B24A948>
# <__main__.Opt_put_hist object at 0x000001FB3B24AA48>
# <__main__.Opt_put_hist object at 0x000001FB3B24AB48>
# <__main__.Opt_put_hist object at 0x000001FB3B24AC48>
# <__main__.Opt_put_hist object at 0x000001FB3B24AD48>
# <__main__.Opt_put_hist object at 0x000001FB3B24AE48>
# <__main__.Opt_put_hist object at 0x000001FB3B24AF48>
# <__main__.Opt_put_hist object at 0x000001FB3B26B088>
# <__main__.Opt_put_hist object at 0x000001FB3B26B188>
# <__main__.Opt_put_hist object at 0x000001FB3B26B288>
# <__main__.Opt_put_hist object at 0x000001FB3B26B388>
# <__main__.Opt_put_hist object at 0x000001FB3B26B488>
# <__main__.Opt_put_hist object at 0x000001FB3B26B588>
# <__main__.Opt_put_hist object at 0x000001FB3B26B688>
# <__main__.Opt_put_hist object at 0x000001FB3B26B788>
# <__main__.Opt_put_hist object at 0x000001FB3B26B888>
# <__main__.Opt_put_hist object at 0x000001FB3B26B988>
# <__main__.Opt_put_hist object at 0x000001FB3B26BA88>
# <__main__.Opt_put_hist object at 0x000001FB3B26BB88>
# <__main__.Opt_put_hist object at 0x000001FB3B26BC88>
# <__main__.Opt_put_hist object at 0x000001FB3B26BD88>
# <__main__.Opt_put_hist object at 0x000001FB3B26BE88>
# <__main__.Opt_put_hist object at 0x000001FB3B26BF88>
# <__main__.Opt_put_hist object at 0x000001FB3B2940C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2941C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2942C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2943C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2944C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2945C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2946C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2947C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2948C8>
# <__main__.Opt_put_hist object at 0x000001FB3B2949C8>
# <__main__.Opt_put_hist object at 0x000001FB3B294AC8>
# <__main__.Opt_put_hist object at 0x000001FB3B294BC8>
# <__main__.Opt_put_hist object at 0x000001FB3B294CC8>
# <__main__.Opt_put_hist object at 0x000001FB3B294DC8>
# <__main__.Opt_put_hist object at 0x000001FB3B294EC8>
# <__main__.Opt_put_hist object at 0x000001FB3B294FC8>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE108>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE208>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE308>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE408>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE508>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE608>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE708>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE808>
# <__main__.Opt_put_hist object at 0x000001FB3B2BE908>
# <__main__.Opt_put_hist object at 0x000001FB3B2BEA08>
# <__main__.Opt_put_hist object at 0x000001FB3B2BEB08>
# <__main__.Opt_put_hist object at 0x000001FB3B2BEC08>
# <__main__.Opt_put_hist object at 0x000001FB3B2BED08>
# <__main__.Opt_put_hist object at 0x000001FB3B2BEE08>
# <__main__.Opt_put_hist object at 0x000001FB3B2BEF08>
# <__main__.Opt_put_hist object at 0x000001FB3B321048>
# <__main__.Opt_put_hist object at 0x000001FB3B321148>
# <__main__.Opt_put_hist object at 0x000001FB3B321248>
# <__main__.Opt_put_hist object at 0x000001FB3B321348>
# <__main__.Opt_put_hist object at 0x000001FB3B321448>
# <__main__.Opt_put_hist object at 0x000001FB3B321548>
# <__main__.Opt_put_hist object at 0x000001FB3B321648>
# <__main__.Opt_put_hist object at 0x000001FB3B321748>
# <__main__.Opt_put_hist object at 0x000001FB3B321848>
# <__main__.Opt_put_hist object at 0x000001FB3B321948>
# <__main__.Opt_put_hist object at 0x000001FB3B321A48>
# <__main__.Opt_put_hist object at 0x000001FB3B321B48>
# <__main__.Opt_put_hist object at 0x000001FB3B321C48>
# <__main__.Opt_put_hist object at 0x000001FB3B321D48>
# <__main__.Opt_put_hist object at 0x000001FB3B321E48>
# <__main__.Opt_put_hist object at 0x000001FB3B321F48>
# <__main__.Opt_put_hist object at 0x000001FB3B34A088>
# <__main__.Opt_put_hist object at 0x000001FB3B34A188>
# <__main__.Opt_put_hist object at 0x000001FB3B34A288>
# <__main__.Opt_put_hist object at 0x000001FB3B34A388>
# <__main__.Opt_put_hist object at 0x000001FB3B34A488>
# <__main__.Opt_put_hist object at 0x000001FB3B34A588>
# <__main__.Opt_put_hist object at 0x000001FB3B34A688>
# <__main__.Opt_put_hist object at 0x000001FB3B34A788>
# <__main__.Opt_put_hist object at 0x000001FB3B34A888>
# <__main__.Opt_put_hist object at 0x000001FB3B34A988>
# <__main__.Opt_put_hist object at 0x000001FB3B34AA88>
# <__main__.Opt_put_hist object at 0x000001FB3B34AB88>
# <__main__.Opt_put_hist object at 0x000001FB3B34AC88>
# <__main__.Opt_put_hist object at 0x000001FB3B34AD88>
# <__main__.Opt_put_hist object at 0x000001FB3B34AE88>
# <__main__.Opt_put_hist object at 0x000001FB3B34AF88>
# <__main__.Opt_put_hist object at 0x000001FB3B3740C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3741C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3742C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3743C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3744C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3745C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3746C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3747C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3748C8>
# <__main__.Opt_put_hist object at 0x000001FB3B3749C8>
# <__main__.Opt_put_hist object at 0x000001FB3B374AC8>
# <__main__.Opt_put_hist object at 0x000001FB3B374BC8>
# <__main__.Opt_put_hist object at 0x000001FB3B374CC8>
# <__main__.Opt_put_hist object at 0x000001FB3B374DC8>
# <__main__.Opt_put_hist object at 0x000001FB3B374EC8>
# <__main__.Opt_put_hist object at 0x000001FB3B374FC8>
# <__main__.Opt_put_hist object at 0x000001FB3B396108>
# <__main__.Opt_put_hist object at 0x000001FB3B396208>
# <__main__.Opt_put_hist object at 0x000001FB3B396308>
# <__main__.Opt_put_hist object at 0x000001FB3B396408>
# <__main__.Opt_put_hist object at 0x000001FB3B396508>
# <__main__.Opt_put_hist object at 0x000001FB3B396608>
# <__main__.Opt_put_hist object at 0x000001FB3B396708>
# <__main__.Opt_put_hist object at 0x000001FB3B396808>
# <__main__.Opt_put_hist object at 0x000001FB3B396908>
# <__main__.Opt_put_hist object at 0x000001FB3B396A08>
# <__main__.Opt_put_hist object at 0x000001FB3B396B08>
# <__main__.Opt_put_hist object at 0x000001FB3B396C08>
# <__main__.Opt_put_hist object at 0x000001FB3B396D08>
# <__main__.Opt_put_hist object at 0x000001FB3B396E08>
# <__main__.Opt_put_hist object at 0x000001FB3B396F08>
# <__main__.Opt_put_hist object at 0x000001FB3B400048>
# <__main__.Opt_put_hist object at 0x000001FB3B400148>
# <__main__.Opt_put_hist object at 0x000001FB3B400248>
# ...
# <__main__.Opt_put_hist object at 0x000001FB3CC17748>
# <__main__.Opt_put_hist object at 0x000001FB3CC17848>
# <__main__.Opt_put_hist object at 0x000001FB3CC17948>
# <__main__.Opt_put_hist object at 0x000001FB3CC17A48>
# <__main__.Opt_put_hist object at 0x000001FB3CC17B48>
# <__main__.Opt_put_hist object at 0x000001FB3CC17C48>
# <__main__.Opt_put_hist object at 0x000001FB3CC17D48>
# <__main__.Opt_put_hist object at 0x000001FB3CC17E48>
# <__main__.Opt_put_hist object at 0x000001FB3CC17F48>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B088>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B188>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B288>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B388>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B488>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B588>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B688>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B788>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B888>
# <__main__.Opt_put_hist object at 0x000001FB3CC1B988>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BA88>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BB88>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BC88>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BD88>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BE88>
# <__main__.Opt_put_hist object at 0x000001FB3CC1BF88>
# <__main__.Opt_put_hist object at 0x000001FB3CC210C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC211C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC212C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC213C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC214C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC215C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC216C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC217C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC218C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC219C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21AC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21BC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21CC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21DC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21EC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC21FC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC25108>
# <__main__.Opt_put_hist object at 0x000001FB3CC25208>
# <__main__.Opt_put_hist object at 0x000001FB3CC25308>
# <__main__.Opt_put_hist object at 0x000001FB3CC25408>
# <__main__.Opt_put_hist object at 0x000001FB3CC25508>
# <__main__.Opt_put_hist object at 0x000001FB3CC25608>
# <__main__.Opt_put_hist object at 0x000001FB3CC25708>
# <__main__.Opt_put_hist object at 0x000001FB3CC25808>
# <__main__.Opt_put_hist object at 0x000001FB3CC25908>
# <__main__.Opt_put_hist object at 0x000001FB3CC25A08>
# <__main__.Opt_put_hist object at 0x000001FB3CC25B08>
# <__main__.Opt_put_hist object at 0x000001FB3CC25C08>
# <__main__.Opt_put_hist object at 0x000001FB3CC25D08>
# <__main__.Opt_put_hist object at 0x000001FB3CC25E08>
# <__main__.Opt_put_hist object at 0x000001FB3CC25F08>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B048>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B148>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B248>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B348>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B448>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B548>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B648>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B748>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B848>
# <__main__.Opt_put_hist object at 0x000001FB3CC2B948>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BA48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BB48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BC48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BD48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BE48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2BF48>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F088>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F188>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F288>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F388>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F488>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F588>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F688>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F788>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F888>
# <__main__.Opt_put_hist object at 0x000001FB3CC2F988>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FA88>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FB88>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FC88>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FD88>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FE88>
# <__main__.Opt_put_hist object at 0x000001FB3CC2FF88>
# <__main__.Opt_put_hist object at 0x000001FB3CC340C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC341C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC342C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC343C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC344C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC345C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC346C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC347C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC348C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC349C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34AC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34BC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34CC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34DC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34EC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC34FC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC39108>
# <__main__.Opt_put_hist object at 0x000001FB3CC39208>
# <__main__.Opt_put_hist object at 0x000001FB3CC39308>
# <__main__.Opt_put_hist object at 0x000001FB3CC39408>
# <__main__.Opt_put_hist object at 0x000001FB3CC39508>
# <__main__.Opt_put_hist object at 0x000001FB3CC39608>
# <__main__.Opt_put_hist object at 0x000001FB3CC39708>
# <__main__.Opt_put_hist object at 0x000001FB3CC39808>
# <__main__.Opt_put_hist object at 0x000001FB3CC39908>
# <__main__.Opt_put_hist object at 0x000001FB3CC39A08>
# <__main__.Opt_put_hist object at 0x000001FB3CC39B08>
# <__main__.Opt_put_hist object at 0x000001FB3CC39C08>
# <__main__.Opt_put_hist object at 0x000001FB3CC39D08>
# <__main__.Opt_put_hist object at 0x000001FB3CC39E08>
# <__main__.Opt_put_hist object at 0x000001FB3CC39F08>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E048>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E148>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E248>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E348>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E448>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E548>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E648>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E748>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E848>
# <__main__.Opt_put_hist object at 0x000001FB3CC3E948>
# <__main__.Opt_put_hist object at 0x000001FB3CC3EA48>
# <__main__.Opt_put_hist object at 0x000001FB3CC3EB48>
# <__main__.Opt_put_hist object at 0x000001FB3CC3EC48>
# <__main__.Opt_put_hist object at 0x000001FB3CC3ED48>
# <__main__.Opt_put_hist object at 0x000001FB3CC3EE48>
# <__main__.Opt_put_hist object at 0x000001FB3CC3EF48>
# <__main__.Opt_put_hist object at 0x000001FB3CC42088>
# <__main__.Opt_put_hist object at 0x000001FB3CC42188>
# <__main__.Opt_put_hist object at 0x000001FB3CC42288>
# <__main__.Opt_put_hist object at 0x000001FB3CC42388>
# <__main__.Opt_put_hist object at 0x000001FB3CC42488>
# <__main__.Opt_put_hist object at 0x000001FB3CC42588>
# <__main__.Opt_put_hist object at 0x000001FB3CC42688>
# <__main__.Opt_put_hist object at 0x000001FB3CC42788>
# <__main__.Opt_put_hist object at 0x000001FB3CC42888>
# <__main__.Opt_put_hist object at 0x000001FB3CC42988>
# <__main__.Opt_put_hist object at 0x000001FB3CC42A88>
# <__main__.Opt_put_hist object at 0x000001FB3CC42B88>
# <__main__.Opt_put_hist object at 0x000001FB3CC42C88>
# <__main__.Opt_put_hist object at 0x000001FB3CC42D88>
# <__main__.Opt_put_hist object at 0x000001FB3CC42E88>
# <__main__.Opt_put_hist object at 0x000001FB3CC42F88>
# <__main__.Opt_put_hist object at 0x000001FB3CC470C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC471C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC472C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC473C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC474C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC475C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC476C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC477C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC478C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC479C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47AC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47BC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47CC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47DC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47EC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC47FC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C108>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C208>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C308>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C408>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C508>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C608>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C708>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C808>
# <__main__.Opt_put_hist object at 0x000001FB3CC4C908>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CA08>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CB08>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CC08>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CD08>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CE08>
# <__main__.Opt_put_hist object at 0x000001FB3CC4CF08>
# <__main__.Opt_put_hist object at 0x000001FB3CC50048>
# <__main__.Opt_put_hist object at 0x000001FB3CC50148>
# <__main__.Opt_put_hist object at 0x000001FB3CC50248>
# <__main__.Opt_put_hist object at 0x000001FB3CC50348>
# <__main__.Opt_put_hist object at 0x000001FB3CC50448>
# <__main__.Opt_put_hist object at 0x000001FB3CC50548>
# <__main__.Opt_put_hist object at 0x000001FB3CC50648>
# <__main__.Opt_put_hist object at 0x000001FB3CC50748>
# <__main__.Opt_put_hist object at 0x000001FB3CC50848>
# <__main__.Opt_put_hist object at 0x000001FB3CC50948>
# <__main__.Opt_put_hist object at 0x000001FB3CC50A48>
# <__main__.Opt_put_hist object at 0x000001FB3CC50B48>
# <__main__.Opt_put_hist object at 0x000001FB3CC50C48>
# <__main__.Opt_put_hist object at 0x000001FB3CC50D48>
# <__main__.Opt_put_hist object at 0x000001FB3CC50E48>
# <__main__.Opt_put_hist object at 0x000001FB3CC50F48>
# <__main__.Opt_put_hist object at 0x000001FB3CC56088>
# <__main__.Opt_put_hist object at 0x000001FB3CC56188>
# <__main__.Opt_put_hist object at 0x000001FB3CC56288>
# <__main__.Opt_put_hist object at 0x000001FB3CC56388>
# <__main__.Opt_put_hist object at 0x000001FB3CC56488>
# <__main__.Opt_put_hist object at 0x000001FB3CC56588>
# <__main__.Opt_put_hist object at 0x000001FB3CC56688>
# <__main__.Opt_put_hist object at 0x000001FB3CC56788>
# <__main__.Opt_put_hist object at 0x000001FB3CC56888>
# <__main__.Opt_put_hist object at 0x000001FB3CC56988>
# <__main__.Opt_put_hist object at 0x000001FB3CC56A88>
# <__main__.Opt_put_hist object at 0x000001FB3CC56B88>
# <__main__.Opt_put_hist object at 0x000001FB3CC56C88>
# <__main__.Opt_put_hist object at 0x000001FB3CC56D88>
# <__main__.Opt_put_hist object at 0x000001FB3CC56E88>
# <__main__.Opt_put_hist object at 0x000001FB3CC56F88>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A0C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A1C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A2C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A3C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A4C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A5C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A6C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A7C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A8C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5A9C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5AAC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5ABC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5ACC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5ADC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5AEC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC5AFC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC60108>
# <__main__.Opt_put_hist object at 0x000001FB3CC60208>
# <__main__.Opt_put_hist object at 0x000001FB3CC60308>
# <__main__.Opt_put_hist object at 0x000001FB3CC60408>
# <__main__.Opt_put_hist object at 0x000001FB3CC60508>
# <__main__.Opt_put_hist object at 0x000001FB3CC60608>
# <__main__.Opt_put_hist object at 0x000001FB3CC60708>
# <__main__.Opt_put_hist object at 0x000001FB3CC60808>
# <__main__.Opt_put_hist object at 0x000001FB3CC60908>
# <__main__.Opt_put_hist object at 0x000001FB3CC60A08>
# <__main__.Opt_put_hist object at 0x000001FB3CC60B08>
# <__main__.Opt_put_hist object at 0x000001FB3CC60C08>
# <__main__.Opt_put_hist object at 0x000001FB3CC60D08>
# <__main__.Opt_put_hist object at 0x000001FB3CC60E08>
# <__main__.Opt_put_hist object at 0x000001FB3CC60F08>
# <__main__.Opt_put_hist object at 0x000001FB3CC65048>
# <__main__.Opt_put_hist object at 0x000001FB3CC65148>
# <__main__.Opt_put_hist object at 0x000001FB3CC65248>
# <__main__.Opt_put_hist object at 0x000001FB3CC65348>
# <__main__.Opt_put_hist object at 0x000001FB3CC65448>
# <__main__.Opt_put_hist object at 0x000001FB3CC65548>
# <__main__.Opt_put_hist object at 0x000001FB3CC65648>
# <__main__.Opt_put_hist object at 0x000001FB3CC65748>
# <__main__.Opt_put_hist object at 0x000001FB3CC65848>
# <__main__.Opt_put_hist object at 0x000001FB3CC65948>
# <__main__.Opt_put_hist object at 0x000001FB3CC65A48>
# <__main__.Opt_put_hist object at 0x000001FB3CC65B48>
# <__main__.Opt_put_hist object at 0x000001FB3CC65C48>
# <__main__.Opt_put_hist object at 0x000001FB3CC65D48>
# <__main__.Opt_put_hist object at 0x000001FB3CC65E48>
# <__main__.Opt_put_hist object at 0x000001FB3CC65F48>
# <__main__.Opt_put_hist object at 0x000001FB3CC68088>
# <__main__.Opt_put_hist object at 0x000001FB3CC68188>
# <__main__.Opt_put_hist object at 0x000001FB3CC68288>
# <__main__.Opt_put_hist object at 0x000001FB3CC68388>
# <__main__.Opt_put_hist object at 0x000001FB3CC68488>
# <__main__.Opt_put_hist object at 0x000001FB3CC68588>
# <__main__.Opt_put_hist object at 0x000001FB3CC68688>
# <__main__.Opt_put_hist object at 0x000001FB3CC68788>
# <__main__.Opt_put_hist object at 0x000001FB3CC68888>
# <__main__.Opt_put_hist object at 0x000001FB3CC68988>
# <__main__.Opt_put_hist object at 0x000001FB3CC68A88>
# <__main__.Opt_put_hist object at 0x000001FB3CC68B88>
# <__main__.Opt_put_hist object at 0x000001FB3CC68C88>
# <__main__.Opt_put_hist object at 0x000001FB3CC68D88>
# <__main__.Opt_put_hist object at 0x000001FB3CC68E88>
# <__main__.Opt_put_hist object at 0x000001FB3CC68F88>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E0C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E1C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E2C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E3C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E4C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E5C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E6C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E7C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E8C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6E9C8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6EAC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6EBC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6ECC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6EDC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6EEC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC6EFC8>
# <__main__.Opt_put_hist object at 0x000001FB3CC72108>
# <__main__.Opt_put_hist object at 0x000001FB3CC72208>
# <__main__.Opt_put_hist object at 0x000001FB3CC72308>
# <__main__.Opt_put_hist object at 0x000001FB3CC72408>
# <__main__.Opt_put_hist object at 0x000001FB3CC72508>
# <__main__.Opt_put_hist object at 0x000001FB3CC72608>
# <__main__.Opt_put_hist object at 0x000001FB3CC72708>
# <__main__.Opt_put_hist object at 0x000001FB3CC72808>
